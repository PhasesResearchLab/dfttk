# %% [markdown]
# # Load modules

# %%
# %load_ext autoreload
# %autoreload 2

# Standard library imports
import pickle

# Third-party library imports
import numpy as np

# DFTTK imports
from dfttk.thermal_electronic.functions import ThermalElectronic

# %% [markdown]
# # test_read_total_electron_dos()

# %%
# Set the path to the VASP configuration directory and initialize the ThermalElectronic object
config_Al_path = "../vasp_data/Al/config_Al"
thermal_electronic = ThermalElectronic()

# %%
# For all volumes:

# Read electron DOS from elec_* folders
thermal_electronic.read_total_electron_dos(path=config_Al_path)

# Print expected results for verification
print(thermal_electronic.path)
print(thermal_electronic.number_of_atoms)
print(thermal_electronic.volumes)
print(thermal_electronic.energies_list)
print(thermal_electronic.dos_list)

# Save energies_list and dos_list to pickle files (these arrays are large)
with open("expected_energies_list.pkl", "wb") as f:
    pickle.dump(thermal_electronic.energies_list, f)
with open("expected_dos_list.pkl", "wb") as f:
    pickle.dump(thermal_electronic.dos_list, f)
# Out:
# /jet/home/nhew/.local/lib/python3.12/site-packages/pymatgen/io/vasp/outputs.py:1285: UserWarning: No POTCAR file with matching TITEL fields was found in
#
#   if potcar := self.get_potcars(path):
# /jet/home/nhew/.local/lib/python3.12/site-packages/pymatgen/io/vasp/outputs.py:1296: UserWarning: No POTCAR file with matching TITEL fields was found in
#
#   potcar = self.get_potcars(path)
# ../vasp_data/Al/config_Al
# 4
# [60. 62. 64. 66. 68. 70. 72. 74.]
# [array([-16.14507986, -16.13547986, -16.12587986, ...,  79.54112014,
#         79.55062014,  79.56022014]), array([-15.81409607, -15.80469607, -15.79529607, ...,  77.81950393,
#         77.82890393,  77.83820393]), array([-15.49769456, -15.48859456, -15.47939456, ...,  76.18480544,
#         76.19400544,  76.20310544]), array([-15.19526904, -15.18626904, -15.17726904, ...,  74.63303096,
#         74.64203096,  74.65103096]), array([-14.90544578, -14.89664578, -14.88784578, ...,  73.15975422,
#         73.16855422,  73.17735422]), array([-14.62820387, -14.61950387, -14.61090387, ...,  71.75729613,
#         71.76589613,  71.77449613]), array([-14.36286472, -14.35436472, -14.34586472, ...,  70.42043528,
#         70.42893528,  70.43733528]), array([-14.10871788, -14.10041788, -14.09211788, ...,  69.14698212,
#         69.15538212,  69.16368212])]
# [array([0., 0., 0., ..., 0., 0., 0.]), array([0., 0., 0., ..., 0., 0., 0.]), array([0., 0., 0., ..., 0., 0., 0.]), array([0., 0., 0., ..., 0., 0., 0.]), array([0., 0., 0., ..., 0., 0., 0.]), array([0., 0., 0., ..., 0., 0., 0.]), array([0., 0., 0., ..., 0., 0., 0.]), array([0., 0., 0., ..., 0., 0., 0.])]

# %%
# For selected volumes:

selected_volumes = np.array([60., 66.])

# Read electron DOS from elec_* folders
thermal_electronic.read_total_electron_dos(path=config_Al_path, selected_volumes=selected_volumes)

# Print expected results for verification
print(thermal_electronic.path)
print(thermal_electronic.number_of_atoms)
print(thermal_electronic.volumes)
print(thermal_electronic.energies_list)
print(thermal_electronic.dos_list)
# Out:
# ../vasp_data/Al/config_Al
# 4
# [60. 66.]
# [array([-16.14507986, -16.13547986, -16.12587986, ...,  79.54112014,
#         79.55062014,  79.56022014]), array([-15.19526904, -15.18626904, -15.17726904, ...,  74.63303096,
#         74.64203096,  74.65103096])]
# [array([0., 0., 0., ..., 0., 0., 0.]), array([0., 0., 0., ..., 0., 0., 0.])]

# %%
# For invalid selected volumes (should raise an error):

selected_volumes = np.array([59., 66.])

# Read electron DOS from elec_* folders
thermal_electronic.read_total_electron_dos(path=config_Al_path, selected_volumes=selected_volumes)

# Print expected results for verification
print(thermal_electronic.path)
print(thermal_electronic.number_of_atoms)
print(thermal_electronic.volumes)
print(thermal_electronic.energies_list)
print(thermal_electronic.dos_list)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 6
#       3 selected_volumes = np.array([59., 66.])
#       5 # Read electron DOS from elec_* folders
# ----> 6 thermal_electronic.read_total_electron_dos(path=config_Al_path, selected_volumes=selected_volumes)
#       8 # Print expected results for verification
#       9 print(thermal_electronic.path)
#
# File /ocean/projects/dmr190011p/nhew/dfttk/dfttk/thermal_electronic/functions.py:156, in ThermalElectronic.read_total_electron_dos(self, path, folder_prefix, vasprun_name, selected_volumes)
#     154 missing = [v for v in selected_volumes if v not in volumes_list]
#     155 if missing:
# --> 156     raise ValueError(f"The following selected volumes were not found: {missing}")
#     158 filtered_volume_list = []
#     159 filtered_num_atoms_list = []
#
# ValueError: The following selected volumes were not found: [59.0]

# %%
# TODO: For inconsistent number of atoms:

# %%
# TODO: Test inconsistent number of electrons:

# %% [markdown]
# # test_set_total_electron_dos()

# %%
# Set the path to the VASP configuration directory and initialize the ThermalElectronic object
thermal_electronic = ThermalElectronic()

# %%
number_of_atoms = 4 
volumes = np.array([60., 62., 64., 66., 68., 70., 72., 74.])

# Load energies_list and dos_list from pickle files
with open("expected_energies_list.pkl", "rb") as f:
    energies_list = pickle.load(f)
with open("expected_dos_list.pkl", "rb") as f:
    dos_list = pickle.load(f)

# Set the electron DOS yourself
thermal_electronic.set_total_electron_dos(
    number_of_atoms=number_of_atoms,
    volumes=volumes,
    energies_list=energies_list,
    dos_list=dos_list
)

# Print expected results for verification
print(thermal_electronic.path)
print(thermal_electronic.number_of_atoms)
print(thermal_electronic.volumes)
print(thermal_electronic.energies_list)
print(thermal_electronic.dos_list)
# Out:
# None
# 4
# [60. 62. 64. 66. 68. 70. 72. 74.]
# [array([-16.14507986, -16.13547986, -16.12587986, ...,  79.54112014,
#         79.55062014,  79.56022014]), array([-15.81409607, -15.80469607, -15.79529607, ...,  77.81950393,
#         77.82890393,  77.83820393]), array([-15.49769456, -15.48859456, -15.47939456, ...,  76.18480544,
#         76.19400544,  76.20310544]), array([-15.19526904, -15.18626904, -15.17726904, ...,  74.63303096,
#         74.64203096,  74.65103096]), array([-14.90544578, -14.89664578, -14.88784578, ...,  73.15975422,
#         73.16855422,  73.17735422]), array([-14.62820387, -14.61950387, -14.61090387, ...,  71.75729613,
#         71.76589613,  71.77449613]), array([-14.36286472, -14.35436472, -14.34586472, ...,  70.42043528,
#         70.42893528,  70.43733528]), array([-14.10871788, -14.10041788, -14.09211788, ...,  69.14698212,
#         69.15538212,  69.16368212])]
# [array([0., 0., 0., ..., 0., 0., 0.]), array([0., 0., 0., ..., 0., 0., 0.]), array([0., 0., 0., ..., 0., 0., 0.]), array([0., 0., 0., ..., 0., 0., 0.]), array([0., 0., 0., ..., 0., 0., 0.]), array([0., 0., 0., ..., 0., 0., 0.]), array([0., 0., 0., ..., 0., 0., 0.]), array([0., 0., 0., ..., 0., 0., 0.])]

# %%
# For different lengths of volumes, energies_list, and dos_list (should raise an error):
number_of_atoms = 4 
volumes = np.array([60., 62., 64., 66., 68., 70., 72.])

# Load energies_list and dos_list from pickle files
with open("expected_energies_list.pkl", "rb") as f:
    energies_list = pickle.load(f)
with open("expected_dos_list.pkl", "rb") as f:
    dos_list = pickle.load(f)

# Set the electron DOS yourself
thermal_electronic.set_total_electron_dos(
    number_of_atoms=number_of_atoms,
    volumes=volumes,
    energies_list=energies_list,
    dos_list=dos_list
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 12
#       9     dos_list = pickle.load(f)
#      11 # Set the electron DOS yourself
# ---> 12 thermal_electronic.set_total_electron_dos(
#      13     number_of_atoms=number_of_atoms,
#      14     volumes=volumes,
#      15     energies_list=energies_list,
#      16     dos_list=dos_list
#      17 )
#
# File /ocean/projects/dmr190011p/nhew/dfttk/dfttk/thermal_electronic/functions.py:220, in ThermalElectronic.set_total_electron_dos(self, number_of_atoms, volumes, energies_list, dos_list)
#     218 # Check that the lengths of volumes, energies_list, and dos_list are the same
#     219 if not (len(volumes) == len(energies_list) == len(dos_list)):
# --> 220     raise ValueError("Lengths of volumes, energies_list, and dos_list must be the same.")
#     222 self.volumes = volumes
#     223 self.energies_list = energies_list
#
# ValueError: Lengths of volumes, energies_list, and dos_list must be the same.

# %% [markdown]
# # test_process()

# %%
# Set the path to the VASP configuration directory and initialize the ThermalElectronic object
config_Al_path = "../vasp_data/Al/config_Al"
thermal_electronic = ThermalElectronic()

# %%
# Process wihout setting the DOS (should raise an error)
thermal_electronic.process(temperatures=np.array([300, 600, 900]))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 2
#       1 # Process wihout setting the DOS (should raise an error)
# ----> 2 thermal_electronic.process(temperatures=np.array([300, 600, 900]))
#
# File /ocean/projects/dmr190011p/nhew/dfttk/dfttk/thermal_electronic/functions.py:241, in ThermalElectronic.process(self, temperatures)
#     239 # If dos_list is None, raise an error
#     240 if self.dos_list is None:
# --> 241     raise ValueError("DOS data not found. Please read or set the total electron DOS first using read_total_electron_dos() or set_total_electron_dos().")
#     243 # Initialize lists to store data
#     244 chemical_potentials_list = []
#
# ValueError: DOS data not found. Please read or set the total electron DOS first using read_total_electron_dos() or set_total_electron_dos().

# %%
# Read electron DOS from elec_* folders for all volumes
thermal_electronic.read_total_electron_dos(path=config_Al_path)
# Out:
# /jet/home/nhew/.local/lib/python3.12/site-packages/pymatgen/io/vasp/outputs.py:1285: UserWarning: No POTCAR file with matching TITEL fields was found in
#
#   if potcar := self.get_potcars(path):
# /jet/home/nhew/.local/lib/python3.12/site-packages/pymatgen/io/vasp/outputs.py:1296: UserWarning: No POTCAR file with matching TITEL fields was found in
#
#   potcar = self.get_potcars(path)

# %%
temperatures = np.array([0, 300, 600, 900])

# Process the thermal electronic properties
thermal_electronic.process(temperatures=temperatures)

print(thermal_electronic.temperatures)
print()
print(thermal_electronic.helmholtz_energies)
print()
print(thermal_electronic.internal_energies)
print()
print(thermal_electronic.entropies)
print()
print(thermal_electronic.heat_capacities)
# Out:
# [  0 300 600 900]
#
# [[-6.73648444e-08 -8.49219646e-08 -6.37930199e-07 -2.47784314e-07
#   -4.17356560e-07 -1.94288120e-07 -8.37631909e-07 -7.06400130e-07]
#  [-1.86812194e-03 -1.94212095e-03 -2.01034372e-03 -2.04885416e-03
#   -2.07876817e-03 -2.11227531e-03 -2.14827701e-03 -2.18280849e-03]
#  [-7.43625295e-03 -7.70784476e-03 -7.95363672e-03 -8.13724063e-03
#   -8.28299483e-03 -8.41321496e-03 -8.54203925e-03 -8.65734626e-03]
#  [-1.65370414e-02 -1.71079727e-02 -1.76229463e-02 -1.80374507e-02
#   -1.83793761e-02 -1.86755333e-02 -1.89589683e-02 -1.92030741e-02]]
#
# [[-6.73648444e-08 -8.49219646e-08 -6.37930199e-07 -2.47784314e-07
#   -4.17356560e-07 -1.94288120e-07 -8.37631909e-07 -7.06400130e-07]
#  [ 1.87288067e-03  1.93643996e-03  1.99433637e-03  2.05074681e-03
#    2.09172870e-03  2.12162543e-03  2.15042343e-03  2.17618076e-03]
#  [ 7.29105411e-03  7.52653664e-03  7.73358755e-03  7.93143942e-03
#    8.10121120e-03  8.23313062e-03  8.34962180e-03  8.44030084e-03]
#  [ 1.59001038e-02  1.63515358e-02  1.67643207e-02  1.71580707e-02
#    1.75173170e-02  1.78240169e-02  1.81024403e-02  1.83270521e-02]]
#
# [[0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#   0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00]
#  [1.24700087e-05 1.29285363e-05 1.33489336e-05 1.36653366e-05
#   1.39016562e-05 1.41130025e-05 1.43290015e-05 1.45299642e-05]
#  [2.45455118e-05 2.53906357e-05 2.61453738e-05 2.67811334e-05
#   2.73070100e-05 2.77439093e-05 2.81527684e-05 2.84960785e-05]
#  [3.60412725e-05 3.71772316e-05 3.82080744e-05 3.91061349e-05
#   3.98852145e-05 4.05550557e-05 4.11793428e-05 4.17001402e-05]]
#
# [[0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#   0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00]
#  [1.23895008e-05 1.28039582e-05 1.31599552e-05 1.35335246e-05
#   1.38546462e-05 1.40612784e-05 1.42335131e-05 1.43632407e-05]
#  [2.35292884e-05 2.42063750e-05 2.48167634e-05 2.53797514e-05
#   2.59075475e-05 2.63707678e-05 2.67862119e-05 2.71075556e-05]
#  [3.37636167e-05 3.45191398e-05 3.52743536e-05 3.60181369e-05
#   3.67568460e-05 3.74607514e-05 3.81281327e-05 3.87085897e-05]]

# %% [markdown]
# # test_fit()

# %%
# Set the path to the VASP configuration directory and initialize the ThermalElectronic object
config_Al_path = "../vasp_data/Al/config_Al"
thermal_electronic = ThermalElectronic()

# %%
# Read electron DOS from elec_* folders for all volumes
thermal_electronic.read_total_electron_dos(path=config_Al_path)

# %%
volumes_fit = np.linspace(0.98*60, 1.02*74, 10)
order = 1

# Try to call fit without process (should raise an error)
thermal_electronic.fit(volumes_fit=volumes_fit, order=order)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[29], line 5
#       2 order = 1
#       4 # Try to call fit without process (should raise an error)
# ----> 5 thermal_electronic.fit(volumes_fit=volumes_fit, order=order)
#
# File /ocean/projects/dmr190011p/nhew/dfttk/dfttk/thermal_electronic/functions.py:301, in ThermalElectronic.fit(self, volumes_fit, order)
#     299 # If helmholtz_energies is None, raise an error
#     300 if self.helmholtz_energies is None:
# --> 301     raise ValueError("Thermodynamic properties not yet calculated. Please call process() first")
#     303 # Initialize lists to store data
#     304 volume_fit_list = []
#
# ValueError: Thermodynamic properties not yet calculated. Please call process() first

# %%
temperatures = np.array([0, 300, 600, 900])

# Process the thermal electronic properties
thermal_electronic.process(temperatures=temperatures)

# %%
volumes_fit = np.linspace(0.98*60, 1.02*74, 10)
order = 1

# Fit the thermal electronic properties vs. volumes for fixed temperatures
thermal_electronic.fit(volumes_fit=volumes_fit, order=order)

print(thermal_electronic.volumes_fit)
print()
print(thermal_electronic.helmholtz_energies_fit)
print()
print(thermal_electronic.entropies_fit)
print()
print(thermal_electronic.heat_capacities_fit)

# poly_coeffs not tested
# Out:
# [58.8        60.65333333 62.50666667 64.36       66.21333333 68.06666667
#  69.92       71.77333333 73.62666667 75.48      ]
#
# [[-5.38607649e-08 -1.31915252e-07 -2.09969739e-07 -2.88024227e-07
#   -3.66078714e-07 -4.44133201e-07 -5.22187688e-07 -6.00242175e-07
#   -6.78296662e-07 -7.56351150e-07]
#  [-1.87473063e-03 -1.91410618e-03 -1.95348174e-03 -1.99285730e-03
#   -2.03223285e-03 -2.07160841e-03 -2.11098396e-03 -2.15035952e-03
#   -2.18973508e-03 -2.22911063e-03]
#  [-7.44612166e-03 -7.60324808e-03 -7.76037450e-03 -7.91750092e-03
#   -8.07462735e-03 -8.23175377e-03 -8.38888019e-03 -8.54600661e-03
#   -8.70313303e-03 -8.86025946e-03]
#  [-1.65318518e-02 -1.68784350e-02 -1.72250181e-02 -1.75716013e-02
#   -1.79181845e-02 -1.82647677e-02 -1.86113509e-02 -1.89579341e-02
#   -1.93045173e-02 -1.96511004e-02]]
#
# [[0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#   0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#   0.00000000e+00 0.00000000e+00]
#  [1.24917905e-05 1.27560068e-05 1.30202230e-05 1.32844393e-05
#   1.35486556e-05 1.38128719e-05 1.40770881e-05 1.43413044e-05
#   1.46055207e-05 1.48697370e-05]
#  [2.45366947e-05 2.50528272e-05 2.55689597e-05 2.60850923e-05
#   2.66012248e-05 2.71173573e-05 2.76334898e-05 2.81496224e-05
#   2.86657549e-05 2.91818874e-05]
#  [3.59397145e-05 3.66837248e-05 3.74277350e-05 3.81717452e-05
#   3.89157554e-05 3.96597657e-05 4.04037759e-05 4.11477861e-05
#   4.18917964e-05 4.26358066e-05]]
#
# [[0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#   0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#   0.00000000e+00 0.00000000e+00]
#  [1.23790583e-05 1.26436993e-05 1.29083404e-05 1.31729814e-05
#   1.34376225e-05 1.37022635e-05 1.39669046e-05 1.42315456e-05
#   1.44961867e-05 1.47608277e-05]
#  [2.34075428e-05 2.38834177e-05 2.43592927e-05 2.48351676e-05
#   2.53110425e-05 2.57869175e-05 2.62627924e-05 2.67386674e-05
#   2.72145423e-05 2.76904172e-05]
#  [3.34021901e-05 3.40636280e-05 3.47250659e-05 3.53865038e-05
#   3.60479416e-05 3.67093795e-05 3.73708174e-05 3.80322553e-05
#   3.86936931e-05 3.93551310e-05]]

# %%
# Set volume to only one value and test fit (should raise an error)
thermal_electronic.volumes = np.array([60.])
thermal_electronic.fit(volumes_fit=volumes_fit, order=order)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 3
#       1 # Set volume to only one value and test fit (should raise an error)
#       2 thermal_electronic.volumes = np.array([60.])
# ----> 3 thermal_electronic.fit(volumes_fit=volumes_fit, order=order)
#
# File /ocean/projects/dmr190011p/nhew/dfttk/dfttk/thermal_electronic/functions.py:308, in ThermalElectronic.fit(self, volumes_fit, order)
#     306 # If there is only one volume, raise an error
#     307 if len(self.volumes) == 1:
# --> 308     raise ValueError("Only one volume found. Need at least two volumes to perform fitting.")
#     310 # Initialize lists to store data
#     311 volume_fit_list = []
#
# ValueError: Only one volume found. Need at least two volumes to perform fitting.

# %% [markdown]
# # test_plot_total_dos()

# %%
# Set the path to the VASP configuration directory and initialize the ThermalElectronic object
config_Al_path = "../vasp_data/Al/config_Al"
thermal_electronic = ThermalElectronic()

# %%
# Try to plot without setting the DOS (should raise an error)
thermal_electronic.plot_total_dos()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 2
#       1 # Try to plot without setting the DOS (should raise an error)
# ----> 2 thermal_electronic.plot_total_dos()
#
# File /ocean/projects/dmr190011p/nhew/dfttk/dfttk/thermal_electronic/functions.py:370, in ThermalElectronic.plot_total_dos(self)
#     368 # If dos_list is None, raise an error
#     369 if self.dos_list is None:
# --> 370     raise ValueError("DOS data not found. Please read or set the total electron DOS first using read_total_electron_dos() or set_total_electron_dos().")
#     372 fig = go.Figure()
#     373 for i in range(len(self.volumes)):
#
# ValueError: DOS data not found. Please read or set the total electron DOS first using read_total_electron_dos() or set_total_electron_dos().

# %%
# Read electron DOS from elec_* folders for all volumes
thermal_electronic.read_total_electron_dos(path=config_Al_path)
# Out:
# /jet/home/nhew/.local/lib/python3.12/site-packages/pymatgen/io/vasp/outputs.py:1285: UserWarning: No POTCAR file with matching TITEL fields was found in
#
#   if potcar := self.get_potcars(path):
# /jet/home/nhew/.local/lib/python3.12/site-packages/pymatgen/io/vasp/outputs.py:1296: UserWarning: No POTCAR file with matching TITEL fields was found in
#
#   potcar = self.get_potcars(path)

# %%
thermal_electronic.plot_total_dos()

# %% [markdown]
# # test_plot_vs_temp()

# %%
# Set the path to the VASP configuration directory and initialize the ThermalElectronic object
config_Al_path = "../vasp_data/Al/config_Al"
thermal_electronic = ThermalElectronic()

# %%
# Read electron DOS from elec_* folders for all volumes
thermal_electronic.read_total_electron_dos(path=config_Al_path)

# %%
# Try to plot without process (should raise an error)
thermal_electronic.plot_vs_temp(property="helmholtz_energy")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[37], line 2
#       1 # Try to plot without process (should raise an error)
# ----> 2 thermal_electronic.plot_vs_temp(property="helmholtz_energy")
#
# File /ocean/projects/dmr190011p/nhew/dfttk/dfttk/thermal_electronic/functions.py:408, in ThermalElectronic.plot_vs_temp(self, property)
#     406 # If helmholtz_energies is None, raise an error
#     407 if self.helmholtz_energies is None:
# --> 408     raise ValueError("Thermodynamic properties not yet calculated. Please call process() first.")
#     410 property_map = {
#     411     "helmholtz_energy": (self.helmholtz_energies, "F<sub>el</sub> (eV)"),
#     412     "entropy": (self.entropies, "S<sub>el</sub> (eV/K)"),
#     413     "heat_capacity": (self.heat_capacities, "C<sub>v,el</sub> (eV/K)"),
#     414 }
#     416 if property not in property_map:
#
# ValueError: Thermodynamic properties not yet calculated. Please call process() first.

# %%
temperatures = np.array([0, 300, 600, 900])

# Process the thermal electronic properties
thermal_electronic.process(temperatures=temperatures)

# %%
# Test the different properties - helmholtz_energy, entropy, heat_capacity
thermal_electronic.plot_vs_temp(property="helmholtz_energy")

# %%
# Test invalid property (should raise an error)
thermal_electronic.plot_vs_volume(property="invalid_property")

# %% [markdown]
# # test_plot_vs_volume()

# %%
# Set the path to the VASP configuration directory and initialize the ThermalElectronic object
config_Al_path = "../vasp_data/Al/config_Al"
thermal_electronic = ThermalElectronic()

# %%
# Read electron DOS from elec_* folders for all volumes
thermal_electronic.read_total_electron_dos(path=config_Al_path)

# %%
# Try to plot without process (should raise an error)
thermal_electronic.plot_vs_volume(property="helmholtz_energy")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[67], line 2
#       1 # Try to plot without process (should raise an error)
# ----> 2 thermal_electronic.plot_vs_volume(property="helmholtz_energy")
#
# File /ocean/projects/dmr190011p/nhew/dfttk/dfttk/thermal_electronic/functions.py:457, in ThermalElectronic.plot_vs_volume(self, property, selected_temperatures)
#     455 # If helmholtz_energies is None, raise an error
#     456 if self.helmholtz_energies is None:
# --> 457     raise ValueError("Thermodynamic properties not yet calculated. Please call process() first.")
#     459 property_map = {
#     460     "helmholtz_energy": (self.helmholtz_energies, self.helmholtz_energies_fit, "F<sub>el</sub> (eV)"),
#     461     "entropy": (self.entropies, self.entropies_fit, "S<sub>el</sub> (eV/K)"),
#     462     "heat_capacity": (self.heat_capacities, self.heat_capacities_fit, "C<sub>v,el</sub> (eV/K)"),
#     463 }
#     465 if property not in property_map:
#
# ValueError: Thermodynamic properties not yet calculated. Please call process() first.

# %%
temperatures = np.array([0, 300, 600, 900])

# Process the thermal electronic properties
thermal_electronic.process(temperatures=temperatures)

# %%
# Test the different properties - helmholtz_energy, entropy, heat_capacity
thermal_electronic.plot_vs_volume(property="helmholtz_energy")

# %%
volumes_fit = np.linspace(0.98*60, 1.02*74, 10)
order = 1

# Fit the thermal electronic properties vs. volumes for fixed temperatures
thermal_electronic.fit(volumes_fit=volumes_fit, order=order)

# %%
# Test the different properties - helmholtz_energy, entropy, heat_capacity
thermal_electronic.plot_vs_volume(property="helmholtz_energy")

# %%
# Test plot for selected temperatures
thermal_electronic.plot_vs_volume(property="helmholtz_energy", selected_temperatures=[300, 900])

# %%
# Test invalid property (should raise an error)
thermal_electronic.plot_vs_volume(property="invalid_property")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[78], line 2
#       1 # Test invalid property (should raise an error)
# ----> 2 thermal_electronic.plot_vs_volume(property="invalid_property")
#
# File /ocean/projects/dmr190011p/nhew/dfttk/dfttk/thermal_electronic/functions.py:466, in ThermalElectronic.plot_vs_volume(self, property, selected_temperatures)
#     459 property_map = {
#     460     "helmholtz_energy": (self.helmholtz_energies, self.helmholtz_energies_fit, "F<sub>el</sub> (eV)"),
#     461     "entropy": (self.entropies, self.entropies_fit, "S<sub>el</sub> (eV/K)"),
#     462     "heat_capacity": (self.heat_capacities, self.heat_capacities_fit, "C<sub>v,el</sub> (eV/K)"),
#     463 }
#     465 if property not in property_map:
# --> 466     raise ValueError("property must be one of 'helmholtz_energy', 'entropy', or 'heat_capacity'")
#     468 property_values, property_values_fit, y_title = property_map[property]
#     470 if selected_temperatures is None:
#
# ValueError: property must be one of 'helmholtz_energy', 'entropy', or 'heat_capacity'
