# %%
from dfttk import workflows
import importlib
from pymatgen.analysis.magnetism.analyzer import CollinearMagneticStructureAnalyzer as CMSA
from pprint import pprint

# %%
path = '/storage/home/lam7027/scratch/16_atoms_or_less_no_big/configurations'
importlib.reload(workflows)
structs = workflows.equivalent_orderings(path)
pprint(structs)
# Out:
# {'254': [], '12': [], '102': [], '348': ['445'], '458': [], '124': ['228'], '5': [], '194': [], '32': ['42'], '321': [], '409': ['291'], '294': ['410'], '134': ['241', '425'], '34': ['44'], '198': [], '150': [], '567': ['572'], '561': [], '572': ['567'], '109': [], '337': ['436'], '539': [], '363': ['365'], '8': ['9'], '273': ['268'], '52': [], '255': [], '127': ['232'], '530': [], '341': ['435'], '391': ['394'], '396': [], '468': ['471'], '132': ['245'], '564': [], '443': ['346'], '593': [], '543': ['545'], '137': ['234'], '99': [], '373': ['377'], '216': ['210'], '274': [], '267': [], '105': ['108'], '555': ['560'], '344': ['444'], '459': [], '467': [], '435': ['341'], '158': ['156'], '465': [], '207': ['204'], '509': [], '596': [], '342': ['440'], '206': ['200'], '234': ['137'], '97': [], '18': [], '338': ['442'], '42': ['32'], '374': ['372'], '65': ['75'], '122': ['237'], '473': [], '441': ['349'], '516': [], '589': ['595'], '179': ['176'], '100': [], '365': ['363'], '67': ['77']
# ...

# %%
pprint(structs)
# Out:
# {'1': [],
#  '100': [],
#  '101': [],
#  '102': [],
#  '103': [],
#  '104': [],
#  '105': ['108'],
#  '107': [],
#  '108': ['105'],
#  '109': [],
#  '11': [],
#  '110': [],
#  '119': ['227'],
#  '12': [],
#  '120': ['235'],
#  '121': ['231'],
#  '122': ['237'],
#  '123': ['230'],
#  '124': ['228'],
#  '125': ['236'],
#  '126': ['233'],
#  '127': ['232'],
#  '128': ['242'],
#  '129': ['229'],
#  '130': ['238'],
#  '132': ['245'],
#  '133': ['239'],
#  '134': ['241', '425'],
#  '137': ['234'],
#  '14': [],
#  '140': ['243'],
#  '146': [],
#  '147': ['149'],
#  '148': [],
#  '149': ['147'],
#  '15': ['16'],
#  '150': [],
#  '151': ['155'],
#  '152': ['159'],
#  '153': [],
#  '154': [],
#  '155': ['151'],
#  '156': ['158'],
#  '157': ['161'],
#  '158': ['156'],
#  '159': ['152'],
#  '16': ['15'],
#  '161': ['157'],
#  '170': [],
#  '171': ['172'],
#  '172': ['171'],
#  '173': [],
#  '174': [],
#  '175': [],
#  '176': ['179'],
#  '177': ['180'],
#  '178': [],
#  '179': ['176'],
# ...

# %%
pprint(structs['8'])
# Out:
# ['9']
